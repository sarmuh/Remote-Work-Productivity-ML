# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("..\data\\raw\\remote_work_productivity.csv")
df.head()
# Out:
#   Employee_ID  Age  Years_Experience  WFH_Days_Per_Week  Gender  \
# 0     EMP0001   39                10                  2  Female
# 1     EMP0002   33                 4                  5  Female
# 2     EMP0003   40                 3                  3    Male
# 3     EMP0004   48                14                  3    Male
# 4     EMP0005   32                 6                  5    Male
#
#     Education_Level Marital_Status Has_Children Location_Type  \
# 0  Associate Degree        Married          Yes         Urban
# 1     Master Degree        Married           No         Urban
# 2               PhD         Single          Yes         Rural
# 3   Bachelor Degree        Married          Yes         Urban
# 4       High School       Divorced          Yes         Rural
#
#          Department  ... Quality_Score Innovation_Score Efficiency_Rating  \
# 0           Product  ...          58.1             52.1              72.1
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                            Age  Years_Experience  WFH_Days_Per_Week  \
# Age                   1.000000          0.663899           0.016873
# Years_Experience      0.663899          1.000000          -0.003754
# WFH_Days_Per_Week     0.016873         -0.003754           1.000000
# Work_Hours_Per_Week  -0.022432          0.007720           0.003936
# Productivity_Score    0.265518          0.253481           0.018172
# Task_Completion_Rate  0.243893          0.218199           0.042617
# Quality_Score         0.259228          0.257541           0.023216
# Innovation_Score      0.181052          0.248338           0.007789
# Efficiency_Rating     0.238945          0.211528           0.012685
# Meetings_Per_Week     0.038832          0.040026          -0.027806
# Commute_Time_Minutes -0.030135          0.004223          -0.437151
# Job_Satisfaction      0.135860          0.138811          -0.001237
# Stress_Level         -0.013226         -0.019017          -0.020237
# ...
